# %%
import anndata
import pandas as pd

# %%
adata = anndata.read_h5ad("I:\\mutiomics\\ICC\\WT_merge.h5ad")
adata2 = anndata.read_h5ad("I:\\mutiomics\\ICC\\h5ad\\anndata_WT.h5ad")

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [Xkr4, Rp1, Sox17, Gm6085, Mrpl15, Lypla1, Gm37988, Tcea1, Rgs20, Atp6v1h, Rb1cc1, 4732440D04Rik, Alkal1, Gm37108, Pcmtd1, Gm26901, Sntg1, Rrs1, Adhfe1, 2610203C22Rik, Vxn, Mybl1, Vcpip1, 1700034P13Rik, Sgk3, Mcmdc2, Snhg6, Ppp1r42, Cops5, Cspp1, Arfgef1, Prex2, A830018L16Rik, Sulf1, Ncoa2, Tram1, Lactb2, Xkr9, Msc, Rpl5-ps1, Kcnb2, Gm37138, Terf1, Sbspon, Rpl7, Rdh10, Stau2, Ube2w, Eloc, Gm7654, Tmem70, Ly96, Gm28376, Jph1, Pi15, Gm16070, Gm28153, Pkhd1, Mcm3, Gm28065, Paqr8, Efhc1, Tram2, Tmem14a, Gsta3, Gm28836, Gm4956, Kcnq5, Gm7658, Rims1, Gm29506, Gm29107, Ogfrl1, B3gat2, Smap1, Sdhaf4, Fam135a, Col19a1, Gm28439, Gm10222, Gm28438, Gm28437, Gm10925, Gm28661, Gm29216, Lmbrd1, Adgrb3, Gm5524, Gm5525, Phf3, Ptp4a1, Ptp4a1-1, 4931428L18Rik, Gm19680, Prim2, Rab23, Bag2, Zfp451, Bend6, Dst, ...]
#
# [17379 rows x 0 columns]

# %%
adata2.var.to_csv("I:\\mutiomics\\ICC\\h5ad\\WT_seq_vars.csv")

# %%
df = pd.DataFrame(adata.X.T, index=adata.var_names, columns=adata.obs_names)

# 将 DataFrame 保存为 CSV 文件
df.to_csv("I:\\mutiomics\\ICC\\h5ad\\transposed_X.csv")

# %%
df
# Out:
#                                                        0          1  \
# Xkr4                                            0.000000   0.653484
# Rp1                                             0.000000   0.000000
# Sox17                                           0.000000   0.000000
# Gm6085                                          0.000000   0.000000
# Mrpl15                                          1.173145   0.653484
# ...                                                  ...        ...
# CDP-DG(18:1(11Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))   0.000000  33.356350
# CL(8:0/8:0/8:0/20:0)                           20.965876   6.858314
# Ganglioside GM3 (d18:1/12:0)                    0.000000   0.000000
# Ganglioside GA2 (d18:1/24:1(15Z))              23.159979   0.000000
# Ganglioside GA2 (d18:1/24:0)                   26.329240   0.000000
#
#                                                        2          3  \
# Xkr4                                            0.000000   0.000000
# ...
